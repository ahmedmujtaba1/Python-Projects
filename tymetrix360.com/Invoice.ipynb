# %%
# Imports
import names
import random
import undetected_chromedriver as uc 
import time
import string
import csv
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
from selenium.webdriver.common.keys import Keys

# %%
chrome_options = uc.ChromeOptions()
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument('--disable-popup-blocking')

driver = uc.Chrome(options=chrome_options)
driver.get("http://www.tymetrix360.com")
actions = ActionChains(driver)

time.sleep(15)
input_holder = driver.find_element(By.ID,"username")
input_holder.send_keys("Nsaini")#your user name
password_holder = driver.find_element(By.ID,"password")
password_holder.send_keys("ManningGAm#22")#your password 

button = driver.find_element(By.ID,"login-button")
button.click()
print("[+] Wait! Logining is Processing....")
time.sleep(8)

driver.find_element(By.XPATH,"(//a[@id='invoiceSearch'])[1]").click()
time.sleep(3)

# %%
try:
    driver.find_element(By.XPATH,"//button[@searchbuttonid='SearchPanel.searchButton']").click()
except:pass

driver.switch_to.default_content()
iframe = driver.find_element(By.ID,"DocumentIFrame")
driver.switch_to.frame(iframe)
list1= driver.find_elements(By.XPATH,"//td[@nowrap='nowrap']//a")
cnt = 5
page = 1
input1= int(input("How many pages you want to scrape : "))

for i in range(input1):
    try:
        time.sleep(8)
        for i in range(len(list1)):

            invoice = driver.find_element(By.XPATH,f"(//td[@nowrap='nowrap']//a)[{cnt}]").text
            xpath = f"(//td[@nowrap='nowrap']//a)[{cnt}]"
            print(f"The Invoice {invoice} xpath is {xpath}")
            cnt += 2

    except:
        try:
            driver.find_element(By.XPATH,"(//a[@title='Next page'])[2]").click()
            time.sleep(10)
            cnt = 5
            page += 1
            print("--------------------------------------------------------------------")
            print("Going to Page no ", page)
        except:pass
# Out:
# How many pages you want to scrape : 70
# The Invoice 74586 xpath is (//td[@nowrap='nowrap']//a)[5]
# The Invoice 70985 xpath is (//td[@nowrap='nowrap']//a)[7]
# The Invoice 68833 xpath is (//td[@nowrap='nowrap']//a)[9]
# The Invoice 66060 xpath is (//td[@nowrap='nowrap']//a)[11]
# The Invoice 70986 xpath is (//td[@nowrap='nowrap']//a)[13]
# The Invoice 77679 xpath is (//td[@nowrap='nowrap']//a)[15]
# The Invoice 79477 xpath is (//td[@nowrap='nowrap']//a)[17]
# The Invoice 86097 xpath is (//td[@nowrap='nowrap']//a)[19]
# The Invoice 86098 xpath is (//td[@nowrap='nowrap']//a)[21]
# The Invoice 82387 xpath is (//td[@nowrap='nowrap']//a)[23]
# --------------------------------------------------------------------
# Going to Page no  2
# The Invoice 86871 xpath is (//td[@nowrap='nowrap']//a)[5]
# The Invoice 89496 xpath is (//td[@nowrap='nowrap']//a)[7]
# The Invoice 92642 xpath is (//td[@nowrap='nowrap']//a)[9]
# The Invoice 92938 xpath is (//td[@nowrap='nowrap']//a)[11]
# ...
