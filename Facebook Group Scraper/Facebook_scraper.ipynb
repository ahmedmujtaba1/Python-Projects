# %% [markdown]
# # Facebook Group Scraping

# %% [markdown]
# ## Rules to follow for this script to run:

# %% [markdown]
# 1. To first run this code you have to press Shift + Enter or you can see Run button (Traingle) you can also press this.
# 2. Then when you run the third cell you have to wait and go to the Chroe that has oppened and at your screen allow the facebook and then run the third cell.
# 3. If you want to access the csv then go on the location where you have imported your Jupyter Notebook.
# 4. If you want the script to stop then click on the square button(Interrupting Kernal button)
#
# Thank You

# %%
# Imports
import names
import random
import undetected_chromedriver as uc 
import time
import string
import csv
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
from selenium.webdriver.common.keys import Keys

# %%
chrome_options = uc.ChromeOptions()
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument('--disable-popup-blocking')

driver = uc.Chrome(options=chrome_options)
driver.get("https://www.facebook.com/groups/3220729401585212/members")

# %%
time.sleep(10)

login_email = 'zionoconnor0@gmail.com'
login_email_input = driver.find_element(By.XPATH, "//*[@type='email']")
login_email_input.send_keys(login_email)
passw = 'A13dsgv?'
password_input = driver.find_element(By.XPATH, "//*[@type='password']")
password_input.send_keys(passw)
sign = driver.find_element(By.XPATH, "(//*[text()='Log in'])[1]")
sign.click()

# %%
import xlsxwriter

names = ['Ahmed', 'Saad Mota', 'Geeks', 'Wiat', 'John']
# Add a number format for cells with money.
workbook = xlsxwriter.Workbook('Facebook_Group-Scraping.xlsx')
font = workbook.add_format({'size': 23, 'underline' : 'single', 'color' : 'FFBB00', 'bold' : True, 'italic': True})
font1 = workbook.add_format({'size': 18, 'underline' : 'single', 'color' : 'FF0000', 'bold' : True, 'italic': True})
font2 = workbook.add_format({'size': 14, 'underline' : 'single', 'color' : 'A020F0', 'bold' : True, 'italic': True})
worksheet = workbook.add_worksheet()

worksheet.write('A1', 'Facebook Group ID', font)
worksheet.write('B1', 'This Person Joined at', font)
worksheet.write('C1', 'Title', font)
worksheet.write('D1', 'Profile ID', font)
worksheet.write('E1', 'Is public Or private', font)
worksheet.write('F1', 'Facebook Messenger ID', font)
worksheet.write('G1 : N1', '1.Post', font)
worksheet.write('O1 : AM1', '2.About', font)
worksheet.write('H2', '1.1 Into', font1)
worksheet.write('I2', '1.2 Studied at', font1)
worksheet.write('J2', '1.3 Lives In', font1)
worksheet.write('K2', '1.4 From', font1)
worksheet.write('L2', '1.5 Relationship', font1)
worksheet.write('M2', '1.6 Mising Field', font1)
worksheet.write('N2', '1.7 Mising Field', font1)
worksheet.write('O2 : S2', '2.1 Over View', font1)
worksheet.write('T2 : X2', '2.2 Work and education', font1)
worksheet.write('Y2 : Z2', '2.3 Places Lived', font1)
worksheet.write('AA2 : AF2', '2.4 Contract and Basic Info', font1)
worksheet.write('AG2 : AH2', '2.5 Family and Relationships', font1)
worksheet.write('AI2 : AL2', '2.6 Details About ', font1)
worksheet.write('AM2', '2.7 Life Events', font1)
worksheet.write('O3', '2.1.1 Work Places', font2)
worksheet.write('P3', '2.1.2 Studied At', font2)
worksheet.write('Q3', '2.1.3 Lives In', font2)
worksheet.write('R3', '2.1.4 From ?', font2)
worksheet.write('S3', '2.1.5 Relationship', font2)
worksheet.write('T3', '2.2.1 Work', font2)
worksheet.write('U3', '2.2.2 University', font2)
worksheet.write('V3', '2.2.3 High School', font2)
worksheet.write('W3', '2.2.4 Hidden Filed 1', font2)
worksheet.write('X3', '2.2.5 Hidden Filed 1', font2)
worksheet.write('Y3', '2.3.1 Current Town/City', font2)
worksheet.write('Z3', '2.3.2 Home Town', font2)
worksheet.write('AA3', '2.4.1 Contact Info', font2)
worksheet.write('AB3', '2.4.2 Websites and Social Links', font2)
worksheet.write('AC3', '2.4.3 Gender', font2)
worksheet.write('AD3', '2.4.4 Date Of Birth', font2)
worksheet.write('AE3', '2.4.5 Birth Year', font2)
worksheet.write('AF3', '2.4.6 Religion', font2)
worksheet.write('AG3', '2.5.1 Relationship', font2)
worksheet.write('AH3', '2.5.2 Family members', font2)
worksheet.write('AI3', '2.6.1 About', font2)
worksheet.write('AJ3', '2.6.2 Name Prounuciation', font2)
worksheet.write('AK3', '2.6.3 Other Name', font2)
worksheet.write('AL3', '2.6.4 Favourite Quotes', font2)
worksheet.write('AN3', '2.6.5 Langauges')

def excel(title, link, joined, idP, profile, ID, Into, education, living, address, workplaces, studied_at, lives, from_, works, uni, school, phone, email, gender, date_of_Birth, BIRTH_year, religion, status, family_mem, about1, pro, other, quotes, events):
    worksheet.write('C4', title)
    worksheet.write('A4', link)
    worksheet.write('B4', joined)
    worksheet.write('D4', idP)
    worksheet.write('E4', profile)
    worksheet.write('F4', ID)
    worksheet.write('H4', Into)
    worksheet.write('I4', education)
    worksheet.write('J4', living)
    worksheet.write('K4', address)
    worksheet.write('O4', workplaces)
    worksheet.write('P4', studied_at)
    worksheet.write('Q4', lives)
    worksheet.write('R4', from_)
    worksheet.write('S4', status)
    worksheet.write('T4', works)
    worksheet.write('U4', uni)
    worksheet.write('V4', school)
    worksheet.write('AA4', phone)
    worksheet.write('AB4', email)
    worksheet.write('AC4', gender)
    worksheet.write('AD4', date_of_Birth)
    worksheet.write('AE4', BIRTH_year)
    worksheet.write('AF4', religion)
    worksheet.write('AG4', status)
    worksheet.write('AH4', family_mem)
    worksheet.write('AI4', about1)
    worksheet.write('AJ4', pro)
    worksheet.write('AK4', other)
    worksheet.write('AL4', quotes)
    worksheet.write('AM4', events)
    workbook.close()

# %%
actions = ActionChains(driver)
cnt = 0
total = 0
no = 5
w = 3
time.sleep(10)

while True:
     
    no += 1
    
    try:
        people = driver.find_element(By.XPATH, f"(//a[@class='x1i10hfl xjbqb8w x6umtig x1b1mbwd xaqea5y xav7gou x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz xt0b8zv xzsf02u x1s688f'])[{no}]")
    except:pass
    
    w +=1
    
    try:
        driver.find_element(By.XPATH, "//*[@class='xvijh9v xhhsvwb x1ty9z65 xgzva0m']").click()
        
    except:pass

    try:
        link = driver.find_element(By.XPATH, f"(//a[@class='x1i10hfl x1qjc9v5 xjbqb8w xjqpnuy xa49m3k xqeqjp1 x2hbi6w x13fuv20 xu3j5b3 x1q0q8m5 x26u7qi x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xdl72j9 x2lah0s xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r x2lwn1j xeuugli xexx8yu x4uap5 x18d9i69 xkhd6sd x1n2onr6 x16tdsg8 x1hl2dhg xggy1nq x1ja2u2z x1t137rt x1o1ewxj x3x9cwd x1e5q0jg x13rtm0m x1q0g3np x87ps6o x1lku1pv x1rg5ohu x1a2a7pz'])[{w}]").get_attribute('href')
    except:pass

    time.sleep(2)
    try:
        joined = driver.find_element(By.XPATH, "//span[@class='x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1nxh6w3 x1sibtaa x1s688f xi81zsa']").text
    except:pass
        

    actions.move_to_element(people).click().perform()
    try:
        people.click()
    
    except:pass
    
    try:
        driver.find_element(By.XPATH, "//*[@class='xvijh9v xhhsvwb x1ty9z65 xgzva0m']").click()
        
    except:pass
    
    time.sleep(10)
    try:
        title = driver.find_element(By.XPATH, "//span[@class='x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x x14qwyeo xw06pyt x579bpy xjkpybl x1xlr1w8 xzsf02u x1yc453h']").text
        print('--------------------------------------------------------------------')
        print("Name : ", title)
        print('Profile Link : ', link)
        print('--------------------------------------------------------------------')
        
        try:
            print('This person joined at : ', joined)
        except:
            print('THis person joined at :  Not Given ')
                
        time.sleep(1)
        info = driver.find_element(By.XPATH, "(//div[@class='x9f619 x1n2onr6 x1ja2u2z x78zum5 xdt5ytf x193iq5w xeuugli x1r8uery x1iyjqo2 xs83m0k xamitd3 xsyo7zv x16hj40l x10b6aqq x1yrsyyn'])[2]").text
        print("Info  : ", info)
        
        driver.find_element(By.XPATH, "//*[@aria-label='See Options']").click()
        time.sleep(2)
    except:pass

    try:
        driver.find_element(By.XPATH, "//a[@class='x1i10hfl xjbqb8w x6umtig x1b1mbwd xaqea5y xav7gou xe8uvvx x1hl2dhg xggy1nq x1o1ewxj x3x9cwd x1e5q0jg x13rtm0m x87ps6o x1lku1pv x1a2a7pz xjyslct x9f619 x1ypdohk x78zum5 x1q0g3np x2lah0s x13mpval x1w4qvff xdj266r xat24cr x1n2onr6 x16tdsg8 x1ja2u2z x6s0dn4 x1y1aw1k x1sxyh0 xwib8y2 xurb0ha']").click()
        time.sleep(10)
        user = "User"
    except:
        try:
            driver.find_element(By.XPATH, "//*[text()='View Main Profile']/..").click()
        except:
            user = "Group"
    
    time.sleep(12)
    
    w = 0
    while w >= 0:
        html = driver.find_element(By.XPATH, "//html")
        html.send_keys(Keys.PAGE_DOWN)
        break
    try:
        driver.find_element(By.XPATH, "//*[text()='Only his friends can see what he shares on his profile.']")
        profile = "Private"
    except:
        profile = "Public"
    
    try:
        Into = driver.find_element(By.XPATH, "//*[@class='x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x xudqn12 x3x7a5m x6prxxf xvq8zen xo1l8bm xzsf02u']").text
    except:
        Into = ''
            
    
    living = ''
    address = ''
    working = ''
    owner_at = ''
    went = ''
    education = ''
    relation = ''
    religion = ''
    
    nav = 0
    for i in range(10):
        nav += 1
        try:    
            a = driver.find_element(By.XPATH, f"(//span[@class='x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x xudqn12 x3x7a5m x6prxxf xvq8zen xo1l8bm xzsf02u x1yc453h'])[{nav}]").text
            
            if 'Lives in' in a:
                living = a
            
            elif 'From' in a:
                address = a

            elif 'Works at' in a:
                working = a

            elif 'Owner at' in a:
                owner_at = a

            elif 'Went to' in a:
                went = a

            elif 'Studied' in a:
                education = a

            elif 'Single' in a:
                relation1 = a
                relation = relation1

            elif 'Married' in a:
                relation2 = a
                relation = relation2

            else:pass

        except:pass
    
    try:
        print('Currently living : ', living)
    except:
        living = ' '
        print('Currently Living : Not Provided !')

    try:
        print('Address : ', address)

    except:
        address = ''
        print('Address : Not Provided !')

    try:
        print("Works at : ", working)

    except:
        working = ''
        print("Works at : Not Provided !")

    try:
        print('Owner at : ', owner_at)

    except:
        owner_at = ''
        print('Owner at : Not Provided !')

    try:
        print('Went to : ', went)

    except:
        went = ''
        print('Went to : Not Provided !')

    try:
        print('Studied at : ', education)

    except:
        education = ''
        print('Studied at : Not Provided !')

    try:
        print('Relationship Status : ', f"{relation}")

    except:
        relation = ''
        print('Relationship Status : Not Provided !')
    
    print('Profile Type : ', profile)
    time.sleep(2)
    w = 0
    while w >= 0:
        html = driver.find_element(By.XPATH, "//html")
        html.send_keys(Keys.PAGE_UP)
        break
    time.sleep(4)
    try:
        about = driver.find_element(By.XPATH, "(//a[@class='x1i10hfl x6umtig x1b1mbwd xaqea5y xav7gou xe8uvvx xggy1nq x1o1ewxj x3x9cwd x1e5q0jg x13rtm0m x87ps6o x1lku1pv x1a2a7pz xjyslct xjbqb8w x18o3ruo x13fuv20 xu3j5b3 x1q0q8m5 x26u7qi x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1heor9g x1ypdohk xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x1n2onr6 x16tdsg8 x1hl2dhg x1vjfegm x3nfvp2 xrbpyxo xng8ra x16dsc37'])[2]").click()
        time.sleep(2)

#         driver.find_element(By.XPATH, "(//a[@class='x1i10hfl xjbqb8w x6umtig x1b1mbwd xaqea5y xav7gou x9f619 x1ypdohk xe8uvvx xdj266r x11i5rnm x1mh8g0r x16tdsg8 x1hl2dhg xggy1nq x87ps6o x1lku1pv x1a2a7pz xhk9q7s x1otrzb0 x1i1ezom x1o6z2jb x1lliihq x12nagc xz9dl7a x1iji9kk xsag5q8 x1sln4lm x1n2onr6'])[3]").click()
#         time.sleep(2)
    except:pass
    
    try:
        workplaces = driver.find_element(By.XPATH, "(//span[@class='x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x xudqn12 x3x7a5m x6prxxf xvq8zen xo1l8bm xzsf02u'])[1]").text
    except:
        workplaces = ''
    
    try:
        studied_at = driver.find_element(By.XPATH,"(//span[@class='x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x xudqn12 x3x7a5m x6prxxf xvq8zen xo1l8bm xzsf02u'])[2]").text
    except:
        studied_at = ''
    
    try:
        lives = driver.find_element(By.XPATH,"(//span[@class='x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x xudqn12 x3x7a5m x6prxxf xvq8zen xo1l8bm xzsf02u'])[3]").text
    except:
        lives = ''
    
    try:
        from_ = driver.find_element(By.XPATH,"(//span[@class='x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x xudqn12 x3x7a5m x6prxxf xvq8zen xo1l8bm xzsf02u'])[4]").text
    except:
        from_ = ''
    
    try:
        status = driver.find_element(By.XPATH,"(//span[@class='x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x xudqn12 x3x7a5m x6prxxf xvq8zen xo1l8bm xzsf02u'])[5]").text
    except:
        status = ''
    
    time.sleep(2)
    try:
        t3 = driver.find_element(By.XPATH,"//a[@class='x1i10hfl x6umtig x1b1mbwd xaqea5y xav7gou x9f619 x1ypdohk xe8uvvx xdj266r x11i5rnm x1mh8g0r x16tdsg8 x1hl2dhg xggy1nq x87ps6o x1lku1pv x1a2a7pz xhk9q7s x1otrzb0 x1i1ezom x1o6z2jb x1lliihq x12nagc xz9dl7a x1iji9kk xsag5q8 x1sln4lm x1n2onr6 x1hr4nm9']")
        t3.click()
    except:pass
    
    time.sleep(3)
    
    try:
        works = driver.find_element(By.XPATH,"(//span[@class='x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x xudqn12 x3x7a5m x6prxxf xvq8zen xo1l8bm xzsf02u'])[1]").text
    except:
        works = ''
        
    try:
        uni = driver.find_element(By.XPATH,"(//span[@class='x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x xudqn12 x3x7a5m x6prxxf xvq8zen xo1l8bm xzsf02u'])[2]").text
    except:
        uni = ''
        
    try:
        school = driver.find_element(By.XPATH,"(//span[@class='x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x xudqn12 x3x7a5m x6prxxf xvq8zen xo1l8bm xzsf02u'])[3]").text
    except:
        school = ''
    
    time.sleep(3)
    
    try:
        t4 = driver.find_element(By.XPATH,"(//a[@class='x1i10hfl xjbqb8w x6umtig x1b1mbwd xaqea5y xav7gou x9f619 x1ypdohk xe8uvvx xdj266r x11i5rnm x1mh8g0r x16tdsg8 x1hl2dhg xggy1nq x87ps6o x1lku1pv x1a2a7pz xhk9q7s x1otrzb0 x1i1ezom x1o6z2jb x1lliihq x12nagc xz9dl7a x1iji9kk xsag5q8 x1sln4lm x1n2onr6'])[2]")
        t4.click()
    except:pass
    
    time.sleep(3)
    
    try:
        town = driver.find_element(By.XPATH,"(//span[@class='xt0psk2']//span)[1]").text
    except:
        town = ''
    
    try:
        home = driver.find_element(By.XPATH,"(//span[@class='xt0psk2']//span)[2]").text
    
    except:
        home = ''
        
    time.sleep(2)
    
    try:
        t5 = driver.find_element(By.XPATH,"(//a[@class='x1i10hfl xjbqb8w x6umtig x1b1mbwd xaqea5y xav7gou x9f619 x1ypdohk xe8uvvx xdj266r x11i5rnm x1mh8g0r x16tdsg8 x1hl2dhg xggy1nq x87ps6o x1lku1pv x1a2a7pz xhk9q7s x1otrzb0 x1i1ezom x1o6z2jb x1lliihq x12nagc xz9dl7a x1iji9kk xsag5q8 x1sln4lm x1n2onr6'])[3]")
        t5.click()
    except:pass
    
    time.sleep(3)
     
    nav2 = 0
    phone = ''
    gender = ''
    email = ''
    
    for i in range(8):
        nav2 += 1
        try:
            q = driver.find_element(By.XPATH, f"(//span[@class='x193iq5w xeuugli x13faqbe x1vvkbs x1xmvt09 x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x xudqn12 x3x7a5m x6prxxf xvq8zen xo1l8bm xzsf02u x1yc453h'])[{nav2}]").text

            if "+" in q:
                phone = q

            elif 'Male' in q:
                gender1 = q
                gender = gender1
                
            elif 'Female'in q:
                gender2 = q
                gender = gender2

            elif 'English' or 'Hindi' in q:
                languages = q
            
            elif '.com' in q:
                email = q
        except:pass
          
    try:
        print('Gender : ', f"{gender}")
    except:
        gender = ''
        print('Gender : Not Provided !')
    
    try:
        print('Phone : ', phone)
    
    except:
        phone = ''
        print('Phone : Not Provided ! ')
        
    try:
        print('Email : ', email)
    
    except:
        phone = ''
        print('Email : Not Provided ! ')
    religion = ''    
    print('Religion : Not Provided !')    
    
    try:
        t6 = driver.find_element(By.XPATH,"(//a[@class='x1i10hfl xjbqb8w x6umtig x1b1mbwd xaqea5y xav7gou x9f619 x1ypdohk xe8uvvx xdj266r x11i5rnm x1mh8g0r x16tdsg8 x1hl2dhg xggy1nq x87ps6o x1lku1pv x1a2a7pz xhk9q7s x1otrzb0 x1i1ezom x1o6z2jb x1lliihq x12nagc xz9dl7a x1iji9kk xsag5q8 x1sln4lm x1n2onr6'])[4]")
        t6.click()
    except:pass
    time.sleep(3)
    
    try:
        family_mem = driver.find_element(By.XPATH,"(//div[@class='x9f619 x1n2onr6 x1ja2u2z x78zum5 xdt5ytf x193iq5w xeuugli x1r8uery x1iyjqo2 xs83m0k xamitd3 xsyo7zv x16hj40l x10b6aqq x1yrsyyn'])[2]").text
    except:
        family_mem = ''
    
    try:
        t7 = driver.find_element(By.XPATH,"(//a[@class='x1i10hfl xjbqb8w x6umtig x1b1mbwd xaqea5y xav7gou x9f619 x1ypdohk xe8uvvx xdj266r x11i5rnm x1mh8g0r x16tdsg8 x1hl2dhg xggy1nq x87ps6o x1lku1pv x1a2a7pz xhk9q7s x1otrzb0 x1i1ezom x1o6z2jb x1lliihq x12nagc xz9dl7a x1iji9kk xsag5q8 x1sln4lm x1n2onr6'])[5]")
        t7.click()
    except:pass
    time.sleep(3)
    
    try:
        about1 = driver.find_element(By.XPATH,"(//div[@class='x9f619 x1n2onr6 x1ja2u2z x78zum5 xdt5ytf x193iq5w xeuugli x1r8uery x1iyjqo2 xs83m0k xamitd3 xsyo7zv x16hj40l x10b6aqq x1yrsyyn'])[1]").text
    except:
        about1 = ''
        
    try:
        pro = driver.find_element(By.XPATH,"(//div[@class='x9f619 x1n2onr6 x1ja2u2z x78zum5 xdt5ytf x193iq5w xeuugli x1r8uery x1iyjqo2 xs83m0k xamitd3 xsyo7zv x16hj40l x10b6aqq x1yrsyyn'])[2]").text
    except:
        pro = ''
        
    try:
        other = driver.find_element(By.XPATH,"(//div[@class='x9f619 x1n2onr6 x1ja2u2z x78zum5 xdt5ytf x193iq5w xeuugli x1r8uery x1iyjqo2 xs83m0k xamitd3 xsyo7zv x16hj40l x10b6aqq x1yrsyyn'])[3]").text
    except:
        other = ''
        
    try:
        quotes = driver.find_element(By.XPATH,"(//div[@class='x9f619 x1n2onr6 x1ja2u2z x78zum5 xdt5ytf x193iq5w xeuugli x1r8uery x1iyjqo2 xs83m0k xamitd3 xsyo7zv x16hj40l x10b6aqq x1yrsyyn'])[4]").text
    except:
        quotes = ''
        
    try:
        t8 = driver.find_element(By.XPATH,"(//a[@class='x1i10hfl xjbqb8w x6umtig x1b1mbwd xaqea5y xav7gou x9f619 x1ypdohk xe8uvvx xdj266r x11i5rnm x1mh8g0r x16tdsg8 x1hl2dhg xggy1nq x87ps6o x1lku1pv x1a2a7pz xhk9q7s x1otrzb0 x1i1ezom x1o6z2jb x1lliihq x12nagc xz9dl7a x1iji9kk xsag5q8 x1sln4lm x1n2onr6'])[6]")
        t8.click()
    except:pass
    time.sleep(2)
    
    try:
        events = driver.find_element(By.XPATH,"(//div[@class='x78zum5 xdt5ytf xz62fqu x16ldp7u'])[2]").text
    
    except:
        events = ''
        
    url_people = driver.find_element(By.XPATH, "(//*[@preserveAspectRatio='xMidYMid slice'])[5]").get_attribute('xlink:href')
    print("IMAGE url : ", url_people)
    
    print('Profile Type : ', user)
    
    time.sleep(3)
    message = driver.find_element(By.XPATH, "//*[@aria-label='Message']")
    message.click()
    time.sleep(1)
    
    ID = driver.find_element(By.XPATH, "//*[@class='x1i10hfl x1qjc9v5 xjbqb8w xjqpnuy xa49m3k xqeqjp1 x2hbi6w x13fuv20 xu3j5b3 x1q0q8m5 x26u7qi x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xdl72j9 x2lah0s xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r x2lwn1j xeuugli xexx8yu x4uap5 x18d9i69 xkhd6sd x1n2onr6 x16tdsg8 x1hl2dhg xggy1nq x1ja2u2z x1t137rt x1o1ewxj x3x9cwd x1e5q0jg x13rtm0m x1q0g3np x87ps6o x1lku1pv x1a2a7pz x78zum5']").text
    print('Messenger ID : ', ID)
    chat = driver.find_element(By.XPATH, "//*[@aria-label='Chat settings']")
    chat.click()
    time.sleep(2)
    
    messanger_link = driver.find_element(By.XPATH, "(//a[@class='x1i10hfl xjbqb8w x6umtig x1b1mbwd xaqea5y xav7gou xe8uvvx x1hl2dhg xggy1nq x1o1ewxj x3x9cwd x1e5q0jg x13rtm0m x87ps6o x1lku1pv x1a2a7pz xjyslct x9f619 x1ypdohk x78zum5 x1q0g3np x2lah0s x13mpval x1w4qvff xdj266r xat24cr x1n2onr6 x16tdsg8 x1ja2u2z x6s0dn4 x1y1aw1k x1sxyh0 xwib8y2 xurb0ha'])[1]").get_attribute('href')

    print('Messanger Link : ', messanger_link)
    
    cnt += 1

    total += 1
    print(total)
    print('==============================================================================================================')
    driver.back()
    driver.back()
    driver.back()
    driver.back()
    driver.back()
    driver.back()
    driver.back()
    driver.back()
    
    date_of_Birth = ''
    BIRTH_year = ''
    time.sleep(12)
    idP = ''
    excel(title, link, joined, idP, profile, ID, Into, education, living, address, workplaces, studied_at, lives, from_, works, uni, school, phone, email, gender, date_of_Birth, BIRTH_year, religion, status, family_mem, about1, pro, other, quotes, events)
    
    try:
        people = driver.find_element(By.XPATH, f"(//a[@class='x1i10hfl xjbqb8w x6umtig x1b1mbwd xaqea5y xav7gou x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz xt0b8zv xzsf02u x1s688f'])[{no}]")
    
    except:
        driver.forward()
    
    time.sleep(12)
# Out:
# --------------------------------------------------------------------
# Name :  Babyjayaraj Das
# Profile Link :  https://www.facebook.com/groups/3220729401585212/user/100004345999310/
# --------------------------------------------------------------------
# This person joined at :  Joined about an hour ago
# Info  :  Member of Malayalai Second Marriage Matrimony -> Widow, Widower, Divorce, Remarriage since 8 December 2022
# Currently living :
# Address :
# Works at :  Works at Social Worker
# Owner at :
# Went to :
# Studied at :  Studied MSW - Master in Social Work at Loyola Academy
# Relationship Status :
# Profile Type :  Public
# Gender :
# Phone :
# Email :
# Religion : Not Provided !
# ...
