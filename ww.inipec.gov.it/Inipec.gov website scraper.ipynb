# %%
# Imports
import names
import random
import undetected_chromedriver as uc 
import time
import string
import csv
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd

# %%
with open('Lead_Scraper.csv','w', newline='',encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Title",'Pec','Province','Tax ID Code','Date Of update'])

# %%
def scraper():
    def get_chrome():
            global driver
            chrome_options = uc.ChromeOptions()
#             chrome_options.add_argument('--load-extension=C:/Users/ABC/Downloads/Ahmed Task/proxy_auth_plugin')
            chrome_options.add_argument("--no-sandbox")
            chrome_options.add_argument("--disable-dev-shm-usage")
            chrome_options.add_argument("--start-maximized")
            chrome_options.add_argument('--disable-popup-blocking')
            chrome_options.add_experimental_option('prefs', {'intl.accept_languages': 'en,en_US'})

            driver = uc.Chrome(options=chrome_options)
            driver.get("https://www.inipec.gov.it/web/guest/cerca-pec?p_p_id=search_pec_SearchPecPortlet_INSTANCE_AXK2wimPmw44&p_p_lifecycle=0&p_p_state=normal&p_p_mode=view&_search_pec_SearchPecPortlet_INSTANCE_AXK2wimPmw44_tabSelected=companies")
    get_chrome()
    time.sleep(10)

    driver.find_element(By.XPATH,"//input[@name='_search_pec_SearchPecPortlet_INSTANCE_AXK2wimPmw44_tax-code-vat']").send_keys(code_input)
    time.sleep(0.7)
    import pyautogui
    x, y = pyautogui.locateCenterOnScreen("captcha.png", confidence=0.8)
    pyautogui.moveTo(x, y)
    #time.sleep(10)
    #x, y = pyautogui.position()
    pyautogui.click(interval=1)

    time.sleep(5)

    driver.find_element(By.XPATH,"//button[@class='aui-button search-pecs-search-button']").click()
    time.sleep(10)

    x, y = pyautogui.locateCenterOnScreen("save1.png", confidence=0.8)
    pyautogui.moveTo(x, y)
    #time.sleep(10)
    #x, y = pyautogui.position()
    pyautogui.click(interval=1)

    pec = driver.find_element(By.XPATH,"(//div[@class='lfr-ddm-field-group form-inline field-wrapper'])[1]").text
    pec = pec.replace("PEC","")
    pec = pec.replace("\n","")
    print(pec)

    province = driver.find_element(By.XPATH,"(//div[@class='lfr-ddm-field-group form-inline field-wrapper'])[2]").text
    province = province.replace("Province","")
    province = province.replace("\n","")
    print(province)

    tax = driver.find_element(By.XPATH,"(//div[@class='lfr-ddm-field-group form-inline field-wrapper'])[3]").text
    tax = tax.replace("Tax ID code","")
    tax = tax.replace("\n","")
    print(tax)

    date = driver.find_element(By.XPATH,"(//div[@class='lfr-ddm-field-group form-inline field-wrapper'])[4]").text
    date = date.replace("Date of update","")
    date = date.replace("Date on which the Business Register communicated the data to INI-PEC","")
    date = date.replace("\n","")
    print(date)

    title = driver.find_element(By.XPATH,"//h3").text
    print(title)

    with open('Lead_Scraper.csv','a', newline='',encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow([title, pec, province, tax, date])

    driver.quit()

# %%
ask = int(input("How many leads you want to scrape? "))
def get_chrome():
    global driver
    chrome_options = uc.ChromeOptions()
#             chrome_options.add_argument('--load-extension=C:/Users/ABC/Downloads/Ahmed Task/proxy_auth_plugin')
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    chrome_options.add_argument("--start-maximized")
    chrome_options.add_argument('--disable-popup-blocking')
    chrome_options.add_experimental_option('prefs', {'intl.accept_languages': 'en,en_US'})

    driver = uc.Chrome(options=chrome_options)
    driver.get("https://www.inipec.gov.it/web/guest/cerca-pec?p_p_id=search_pec_SearchPecPortlet_INSTANCE_AXK2wimPmw44&p_p_lifecycle=0&p_p_state=normal&p_p_mode=view&_search_pec_SearchPecPortlet_INSTANCE_AXK2wimPmw44_tabSelected=companies")
get_chrome()

for i in range(ask):
    code_input = input("Enter Your Tax ID code : ")
    try:
        driver.get("https://www.inipec.gov.it/web/guest/cerca-pec?p_p_id=search_pec_SearchPecPortlet_INSTANCE_AXK2wimPmw44&p_p_lifecycle=0&p_p_state=normal&p_p_mode=view&_search_pec_SearchPecPortlet_INSTANCE_AXK2wimPmw44_tabSelected=companies")
        time.sleep(10)

        driver.find_element(By.XPATH,"//input[@name='_search_pec_SearchPecPortlet_INSTANCE_AXK2wimPmw44_tax-code-vat']").send_keys(code_input)
        time.sleep(0.7)
        import pyautogui
        x, y = pyautogui.locateCenterOnScreen("captcha.png", confidence=0.8)
        pyautogui.moveTo(x, y)
        #time.sleep(10)
        #x, y = pyautogui.position()
        pyautogui.click(interval=1)

        time.sleep(5)

        driver.find_element(By.XPATH,"//button[@class='aui-button search-pecs-search-button']").click()
        time.sleep(10)

        x, y = pyautogui.locateCenterOnScreen("save1.png", confidence=0.8)
        pyautogui.moveTo(x, y)
        #time.sleep(10)
        #x, y = pyautogui.position()
        pyautogui.click(interval=1)

        pec = driver.find_element(By.XPATH,"(//div[@class='lfr-ddm-field-group form-inline field-wrapper'])[1]").text
        pec = pec.replace("PEC","")
        pec = pec.replace("\n","")
        print(pec)

        province = driver.find_element(By.XPATH,"(//div[@class='lfr-ddm-field-group form-inline field-wrapper'])[2]").text
        province = province.replace("Province","")
        province = province.replace("\n","")
        print(province)

        tax = driver.find_element(By.XPATH,"(//div[@class='lfr-ddm-field-group form-inline field-wrapper'])[3]").text
        tax = tax.replace("Tax ID code","")
        tax = tax.replace("\n","")
        print(tax)

        date = driver.find_element(By.XPATH,"(//div[@class='lfr-ddm-field-group form-inline field-wrapper'])[4]").text
        date = date.replace("Date of update","")
        date = date.replace("Date on which the Business Register communicated the data to INI-PEC","")
        date = date.replace("\n","")
        print(date)

        title = driver.find_element(By.XPATH,"//h3").text
        print(title)

        with open('Lead_Scraper.csv','a', newline='',encoding="utf-8") as file:
            writer = csv.writer(file)
            writer.writerow([title, pec, province, tax, date])
            
        driver.quit()
    except:
#         driver.refresh()
    
        scraper()
# Out:
# How many leads you want to scrape? dlk
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11876\1897656390.py in <module>
# ----> 1 ask = int(input("How many leads you want to scrape? "))
#       2 def get_chrome():
#       3     global driver
#       4     chrome_options = uc.ChromeOptions()
#       5 #             chrome_options.add_argument('--load-extension=C:/Users/ABC/Downloads/Ahmed Task/proxy_auth_plugin')
#
# ValueError: invalid literal for int() with base 10: 'dlk'
