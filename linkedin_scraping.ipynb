# %%
try:
    from time import sleep
    import undetected_chromedriver as uc
    from selenium import webdriver
    from selenium.webdriver.chrome.options import Options
    from selenium.webdriver.common.action_chains import ActionChains
    from selenium.webdriver.common.by import By
    from selenium.webdriver.support.ui import WebDriverWait
    from selenium.webdriver.common.keys import Keys
    from selenium.webdriver.support import expected_conditions as EC
    from webdriver_manager.chrome import ChromeDriverManager
except:
    print("Any Module is not download")

def Connect_To_Browser():
    url = 'https://www.linkedin.com/jobs/search/?currentJobId=3308450031&geoId=&keywords=Data%20Scientist&location=canada'
    co = webdriver.ChromeOptions()
    co.add_argument("--start-maximized")
    co.add_argument('--disable-gpu')
    co.add_argument('--disable-infobars')
    co.add_experimental_option("detach", True)
    
    
    driver = driver = webdriver.Chrome(ChromeDriverManager().install(),options=co)
    driver.get(url)
    action = ActionChains(driver)
    
    b = driver.find_elements(By.XPATH, "//*[@data-tracking-control-name='public_jobs_jserp-result_search-card']")
    c = driver.find_elements(By.XPATH, "//*[@class='base-search-card__title']")
    d = driver.find_elements(By.XPATH, "//*[@class='base-search-card__subtitle']")
    e = driver.find_elements(By.XPATH, "//*[@class='job-search-card__location']")
    g = driver.find_elements(By.XPATH, "//*[@class='job-search-card__listdate']")
    
    no_of_pagedowns = 100
    
    elem = driver.find_element(By.XPATH, "//*[@dir='ltr']")

    
    while no_of_pagedowns:
        elem.send_keys(Keys.PAGE_DOWN)
        driver.find_element(By.XPATH, "//*[@aria-label='Load more results']")
        sleep(0.2)
        no_of_pagedowns-=1
    
    jobs_card = driver.find_elements(By.XPATH,"//a[@data-tracking-control-name='public_jobs_jserp-result_search-card']")
    
    jobs_done = []

    for job in jobs_card:

        if job in jobs_done:
            continue
        else:
            jobs_done.append(job)

        action.move_to_element(job).perform()

        job.click()

        sleep(0.5)

        for scraping in range(len(b)):
            try:
                links = b[scraping].get_attribute('href')
                print('Getting links : ', links)
            except:
                links = ' '
                print('Getting Links : ', links)
            
            try:
                Jobs = c[scraping].text
                print('Jobs You Search : ', Jobs)
            except:
                Jobs = ' '
                print('Jobs You Search : ', Jobs)
                
            try:
                Company = d[scraping].text
                print('Company : ', Company)
            except:
                Comapany = ' '
                print('Company : ', Company)
                
            try:
                locations = e[scraping].text
                print('Location Of Company : ', locations)
            except:
                locations = ' '
                print('Location Of Company : ', locations)
                
            try:
                time = g[scraping].text
                print('Time when this job was post :', time)
            except:
                time = ' '
                print('Time when this job was post :', time)

            try:
                #clicks on see more
                driver.find_element(By.XPATH, "//button[@data-tracking-control-name='public_jobs_show-more-html-btn']").click()
            except:pass

            sleep(6)

            details = driver.find_element(By.XPATH, "//*[@class='show-more-less-html show-more-less-html--more']").text
            print('Details : ', details)

        
            print("====================================================================================")

        break
Connect_To_Browser()
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_13244\665571763.py:24: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = driver = webdriver.Chrome(ChromeDriverManager().install(),options=co)
# Getting links :  https://ca.linkedin.com/jobs/view/data-scientist-remote-at-ample-insight-3307919697?refId=CuD4e6Uz%2FxDPUczxlrLrxQ%3D%3D&trackingId
pageNum=0&trk=public_jobs_jserp-result_search-card
# Jobs You Search :  Machine Learning/DeepStream Developer
# Company :  Prometheus Software
# Location Of Company :  Toronto, Ontario, Canada
# Time when this job was post : 1 month ago
# Details :  Company Description
#
# You will join a world-class team of engineers and data scientists from Facebook, Uber, Amazon and Google. We are a fast growing consulting firm based in Toronto with clients ranging from leading startups building impactful technologies to Fortune 500 companies looking to scale their engineering and data capabilities.
#
# Job Description
#
# We are looking for Data Scientists who are passionate about Machine Learning, and have deep knowledge in Statistics and Computer Science. You enjoy doing data science projects with structured and/or unstructured data and are motivated to productize scalable machine learning models. We will also rely on you to build data products to extract valuable business insights. Critical thinking and problem-solving skills are essential for this role.
#
# Qualifications
#
# BS (or higher, e.g., MS, or PhD) in Computer Science or related engineering field involving coding
# Experienced implementing and scaling machine learning models in production environments
# Strong understanding of machine learning theory
# Hands on experience with Statistics
# Capable of quickly implementing prototypes of cutting-edge research papers
# Proficient in Python (i.e. Pandas, Numpy, scikit-learn, etc), R, TensorFlow, amongst other data science related tools and libraries
# Analytical mind and strong business acumen
#
# If you're passionate about data science and is hungry to learn, please apply!
#
# Additional Information
#
# We have very competitive compensation.
#
# Work on cool projects based on your interests and skills. We believe in accountability and NOT micro-management.
# Show less
# ====================================================================================
# Getting links :  https://ca.linkedin.com/jobs/view/data-scientist-at-gsl-group-3289246828?refId=CuD4e6Uz%2FxDPUczxlrLrxQ%3D%3D&trackingId=leyQHieZPw%2FwheOm%2Flfu0Q%3D%3D&position=21&pageNum=0&trk=public_jobs_jserp-result_search-card
# Jobs You Search :  Data Scientist
# Company :  GSL Group
# Location Of Company :  Vancouver, British Columbia, Canada
# Time when this job was post : 11 months ago
# Details :  Company Description
#
# You will join a world-class team of engineers and data scientists from Facebook, Uber, Amazon and Google. We are a fast growing consulting firm based in Toronto with clients ranging from leading startups building impactful technologies to Fortune 500 companies looking to scale their engineering and data capabilities.
#
# Job Description
#
# We are looking for Data Scientists who are passionate about Machine Learning, and have deep knowledge in Statistics and Computer Science. You enjoy doing data science projects with structured and/or unstructured data and are motivated to productize scalable machine learning models. We will also rely on you to build data products to extract valuable business insights. Critical thinking and problem-solving skills are essential for this role.
#
# Qualifications
#
# BS (or higher, e.g., MS, or PhD) in Computer Science or related engineering field involving coding
# Experienced implementing and scaling machine learning models in production environments
# Strong understanding of machine learning theory
# Hands on experience with Statistics
# Capable of quickly implementing prototypes of cutting-edge research papers
# Proficient in Python (i.e. Pandas, Numpy, scikit-learn, etc), R, TensorFlow, amongst other data science related tools and libraries
# Analytical mind and strong business acumen
#
# If you're passionate about data science and is hungry to learn, please apply!
#
# Additional Information
#
# We have very competitive compensation.
#
# Work on cool projects based on your interests and skills. We believe in accountability and NOT micro-management.
# Show less
# ====================================================================================
# Getting links :  https://ca.linkedin.com/jobs/view/data-scientist-at-nuvoola-ai-2817978108?refId=CuD4e6Uz%2FxDPUczxlrLrxQ%3D%3D&trackingId=AqyaHXCjk%2B%2FPTxFQzbAYLg%3D%3D&position=22&pageNum=0&trk=public_jobs_jserp-result_search-card
# Jobs You Search :  Data Scientist
# Company :  Nuvoola AI
# Location Of Company :  Québec, Quebec, Canada
# Time when this job was post : 2 days ago
# Details :  Company Description
#
# You will join a world-class team of engineers and data scientists from Facebook, Uber, Amazon and Google. We are a fast growing consulting firm based in Toronto with clients ranging from leading startups building impactful technologies to Fortune 500 companies looking to scale their engineering and data capabilities.
#
# Job Description
#
# We are looking for Data Scientists who are passionate about Machine Learning, and have deep knowledge in Statistics and Computer Science. You enjoy doing data science projects with structured and/or unstructured data and are motivated to productize scalable machine learning models. We will also rely on you to build data products to extract valuable business insights. Critical thinking and problem-solving skills are essential for this role.
#
# Qualifications
#
# BS (or higher, e.g., MS, or PhD) in Computer Science or related engineering field involving coding
# Experienced implementing and scaling machine learning models in production environments
# Strong understanding of machine learning theory
# Hands on experience with Statistics
# Capable of quickly implementing prototypes of cutting-edge research papers
# Proficient in Python (i.e. Pandas, Numpy, scikit-learn, etc), R, TensorFlow, amongst other data science related tools and libraries
# Analytical mind and strong business acumen
#
# If you're passionate about data science and is hungry to learn, please apply!
#
# Additional Information
#
# We have very competitive compensation.
#
# Work on cool projects based on your interests and skills. We believe in accountability and NOT micro-management.
# Show less
# ====================================================================================
# Getting links :  https://ca.linkedin.com/jobs/view/machine-learning-engineer-at-autometrics-manufacturing-technologies-inc-3321179462?refId=CuD4e6Uz%2FxDPUczxlrLrxQ%3D%3D&trackingId=Y2cWL67QtFBmoIsXxd0p0Q%3D%3D&position=23&pageNum=0&trk=public_jobs_jserp-result_search-card
# Jobs You Search :  Machine Learning Engineer
# Company :  AutoMetrics Manufacturing Technologies Inc
# Location Of Company :  Toronto, Ontario, Canada
# Time when this job was post : 3 weeks ago
# Details :  Company Description
#
# You will join a world-class team of engineers and data scientists from Facebook, Uber, Amazon and Google. We are a fast growing consulting firm based in Toronto with clients ranging from leading startups building impactful technologies to Fortune 500 companies looking to scale their engineering and data capabilities.
#
# Job Description
#
# We are looking for Data Scientists who are passionate about Machine Learning, and have deep knowledge in Statistics and Computer Science. You enjoy doing data science projects with structured and/or unstructured data and are motivated to productize scalable machine learning models. We will also rely on you to build data products to extract valuable business insights. Critical thinking and problem-solving skills are essential for this role.
#
# Qualifications
#
# BS (or higher, e.g., MS, or PhD) in Computer Science or related engineering field involving coding
# Experienced implementing and scaling machine learning models in production environments
# Strong understanding of machine learning theory
# Hands on experience with Statistics
# Capable of quickly implementing prototypes of cutting-edge research papers
# Proficient in Python (i.e. Pandas, Numpy, scikit-learn, etc), R, TensorFlow, amongst other data science related tools and libraries
# Analytical mind and strong business acumen
#
# If you're passionate about data science and is hungry to learn, please apply!
#
# Additional Information
#
# We have very competitive compensation.
#
# Work on cool projects based on your interests and skills. We believe in accountability and NOT micro-management.
# Show less
# ====================================================================================
# Getting links :  https://ca.linkedin.com/jobs/view/data-scientist-at-geocomply-3318542784?refId=CuD4e6Uz%2FxDPUczxlrLrxQ%3D%3D&trackingId=8IzXAz2sauPDUpWB9xSXLw%3D%3D&position=24&pageNum=0&trk=public_jobs_jserp-result_search-card
# Jobs You Search :  Data Scientist
# Company :  GeoComply
# Location Of Company :  Vancouver, British Columbia, Canada
# Time when this job was post : 2 months ago
# Details :  Company Description
#
# You will join a world-class team of engineers and data scientists from Facebook, Uber, Amazon and Google. We are a fast growing consulting firm based in Toronto with clients ranging from leading startups building impactful technologies to Fortune 500 companies looking to scale their engineering and data capabilities.
#
# Job Description
#
# We are looking for Data Scientists who are passionate about Machine Learning, and have deep knowledge in Statistics and Computer Science. You enjoy doing data science projects with structured and/or unstructured data and are motivated to productize scalable machine learning models. We will also rely on you to build data products to extract valuable business insights. Critical thinking and problem-solving skills are essential for this role.
#
# Qualifications
#
# BS (or higher, e.g., MS, or PhD) in Computer Science or related engineering field involving coding
# Experienced implementing and scaling machine learning models in production environments
# Strong understanding of machine learning theory
# Hands on experience with Statistics
# Capable of quickly implementing prototypes of cutting-edge research papers
# Proficient in Python (i.e. Pandas, Numpy, scikit-learn, etc), R, TensorFlow, amongst other data science related tools and libraries
# Analytical mind and strong business acumen
#
# If you're passionate about data science and is hungry to learn, please apply!
#
# Additional Information
#
# We have very competitive compensation.
#
# Work on cool projects based on your interests and skills. We believe in accountability and NOT micro-management.
# Show less
# ====================================================================================
# Getting links :  https://ca.linkedin.com/jobs/view/data-scientist-at-mccain-foods-3217696124?refId=CuD4e6Uz%2FxDPUczxlrLrxQ%3D%3D&trackingId=L8VYZHZ3D8md3U7yJmWNSg%3D%3D&position=25&pageNum=0&trk=public_jobs_jserp-result_search-card
# Jobs You Search :  Data Scientist
# Company :  McCain Foods
# Location Of Company :  Toronto, Ontario, Canada
# Time when this job was post :
# Details :  Company Description
#
# You will join a world-class team of engineers and data scientists from Facebook, Uber, Amazon and Google. We are a fast growing consulting firm based in Toronto with clients ranging from leading startups building impactful technologies to Fortune 500 companies looking to scale their engineering and data capabilities.
#
# Job Description
#
# We are looking for Data Scientists who are passionate about Machine Learning, and have deep knowledge in Statistics and Computer Science. You enjoy doing data science projects with structured and/or unstructured data and are motivated to productize scalable machine learning models. We will also rely on you to build data products to extract valuable business insights. Critical thinking and problem-solving skills are essential for this role.
#
# Qualifications
#
# BS (or higher, e.g., MS, or PhD) in Computer Science or related engineering field involving coding
# Experienced implementing and scaling machine learning models in production environments
# Strong understanding of machine learning theory
# Hands on experience with Statistics
# Capable of quickly implementing prototypes of cutting-edge research papers
# Proficient in Python (i.e. Pandas, Numpy, scikit-learn, etc), R, TensorFlow, amongst other data science related tools and libraries
# Analytical mind and strong business acumen
#
# If you're passionate about data science and is hungry to learn, please apply!
#
# Additional Information
#
# We have very competitive compensation.
#
# Work on cool projects based on your interests and skills. We believe in accountability and NOT micro-management.
# Show less
# ====================================================================================

# %%
import csv

with open("linkedin.csv", "w") as f:
    data_handler = csv.writer(f, delimiter = ',')
    csv_writer =scraping
    data_handler.writerow([title,location,company,job description])
