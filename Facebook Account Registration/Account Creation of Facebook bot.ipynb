# %%
# Imports
import names
import random
import undetected_chromedriver as uc 
import time
import string
import csv
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd

# %%
def get_chrome():
    global driver
    
    chrome_options = uc.ChromeOptions()
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    chrome_options.add_argument("--start-maximized")
    chrome_options.add_argument('--disable-popup-blocking')

    driver = uc.Chrome(options=chrome_options)
    driver.get("https://www.facebook.com/campaign/landing.php?campaign_id=1653377901&extra_1=s%7Cc%7C318305695646%7Ce%7Cfacebook%20sign%20up%7C&placement=&creative=318305695646&keyword=facebook%20sign%20up&partner_id=googlesem&extra_2=campaignid%3D1653377901%26adgroupid%3D65139789722%26matchtype%3De%26network%3Dg%26source%3Dnotmobile%26search_or_content%3Ds%26device%3Dc%26devicemodel%3D%26adposition%3D%26target%3D%26targetid%3Dkwd-5066597374%26loc_physical_ms%3D1011081%26loc_interest_ms%3D%26feeditemid%3D%26param1%3D%26param2%3D&gclid=EAIaIQobChMIqtGI_dvX_AIVlp93Ch0y8gPbEAAYASAAEgIOcvD_BwE")

# %%
'''Like I have import pandas as pd as shown below this means that the module I input should save in "pd" variable'''

# If you want to read excel so you should use ".read_excel" ----
#               |                                               |
#               | 
#               .

#                     file destination                     file name               extension
df = pd.read_excel("C:/Users/ABC/OneDrive/Documents/Copy of 500_Gmails_Account(1).xlsx")
df
# Out:
#                                     Email                        Password  \
# 0                  atkioclarice@gmail.com                    mal567233vch
# 1              chistinanadia458@gmail.com                     uk789112cxh
# 2                 chiomatanner2@gmail.com                    sin678112skx
# 3              zoltanbradford21@gmail.com                    sin678223sxh
# 4             torrisharrison360@gmail.com                    sin567112sxk
# ..                                    ...                             ...
# 523       vaogsosmgslnsk9379268@gmail.com  bskgskbddu9628269586ishksbdjdh
# 524        bbalbsismgsks9628279@gmail.com    gogsldbldbu86282796kshkdbdjd
# 525  nsobsukgsobduskgso96293796@gmail.com  gsohsksbldhu872827286ishjshshd
# 526  bslbsukgslskfsldjrs9379367@gmail.com       hsojskdjld837296kshdjdjjd
# 527           bbsosgkdbkf936927@gmail.com      vsoshlsbsu862826295ishksnd
#
#                            Recovery Email  Column12  Column13  Column14  \
# ...

# %%
n = 1
while n != 10:
    fname = names.get_first_name()
    lname = names.get_last_name()
    rec_email_ = df["Recovery Email"][n]
    email_ = df['Email'][n]# "df" is the variable
    passw = df["Password"][n]
    
    get_chrome()
    wait = WebDriverWait(driver, 15)
    time.sleep(10)
    
    
    '''For entering first Name'''
    fname_holder = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div[2]/div/div[2]/div/div/div[1]/form/div[1]/div[1]/div[1]/div[1]/div/div[1]/input")
    fname_holder.send_keys(fname)
    
    '''For Entering Last Name'''
    time.sleep(2)
    lname_holder = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div[2]/div/div[2]/div/div/div[1]/form/div[1]/div[1]/div[1]/div[2]/div/div[1]/input")
    lname_holder.send_keys(lname)
    
    time.sleep(2)
    # entering email --->                              xpath
    email_holder = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div[2]/div/div[2]/div/div/div[1]/form/div[1]/div[2]/div/div[1]/input")
    email_holder.send_keys(email_)
    
    # enter email again                              xpath
    email_holder = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div[2]/div/div[2]/div/div/div[1]/form/div[1]/div[3]/div/div/div[1]/input")
    email_holder.send_keys(email_)
    time.sleep(2)
    # entering password 
    password = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div[2]/div/div[2]/div/div/div[1]/form/div[1]/div[4]/div/div[1]/input")
    time.sleep(2)
    password.send_keys(passw)
    time.sleep(1)
    print('Email : ', email_, "Password : ", passw)
    time.sleep(2)
        #day
    dayholder = driver.find_element(By.XPATH,"//select[@name='birthday_day']")
    dayholder.send_keys(random.randint(1,28))

    time.sleep(2)
        #month
    monthholder = driver.find_element(By.XPATH,"//select[@name='birthday_month']")
    monthholder.send_keys("March")

    time.sleep(2)
        #year
    yearholder = driver.find_element(By.XPATH,"//select[@name='birthday_year']")
    yearholder.send_keys(random.randint(1983,2006))
    
    time.sleep(1)
    
        #gender                                               using "text()" means that gettig the text of any element (we can also get element by this also)
    gender_holder = driver.find_element(By.XPATH,"//*[text()='Male']")
    gender_holder.click()
    time.sleep(2)
    sign_up = driver.find_element(By.XPATH,"//button[@name='websubmit']")
    sign_up.click()
    
    time.sleep(10)
    
    # Signing Gmail Account
    link_="https://accounts.google.com/v3/signin/identifier?dsh=S-637052758%3A1666389744021673&continue=https%3A%2F%2Fmail.google.com%2Fmail%2Fu%2F0%2F&emr=1&followup=https%3A%2F%2Fmail.google.com%2Fmail%2Fu%2F0%2F&osid=1&passive=1209600&service=mail&flowName=GlifWebSignIn&flowEntry=ServiceLogin&ifkv=AQDHYWo5xUf5kqvA2wZ4PM7VY76MS6UK1NV7idf5t_blXMDIlCU2bqYNTNTw_87WkHbPB_mLTY8I"

    driver.execute_script("window.open('');")#will open blank tab
    # Switch to the new window
    driver.switch_to.window(driver.window_handles[1])#1 MEANS 2ND TAB
    driver.get(link_)#get link_ 
    time.sleep(3)#sleeping code
    
    time.sleep(10)
    
    try:
        driver.find_element(By.XPATH, f"//input[@type='email']").send_keys(email_)
        time.sleep(3)
        driver.find_element(By.XPATH, f"//span[text()='Next']/..").click()
        time.sleep(12)
    except:
        try:
            driver.find_element(By.XPATH, f"//span[text()='Next']/..").click()
        except:pass

    time.sleep(4)
    driver.find_element(By.XPATH, f"//input[@type='password']").send_keys(passw)

    driver.find_element(By.XPATH, f"//span[text()='Next']/..").click()
    time.sleep(2)
    

    try:
        wait.until(EC.presence_of_element_located((By.XPATH, f"//div[text()='Confirm your recovery email']/.."))).click()

        time.sleep(6)

        wait.until(EC.presence_of_element_located((By.XPATH, f"//input[@type='email']"))).send_keys(rec_email_)

        time.sleep(2)

        wait.until(EC.presence_of_element_located((By.XPATH, f"//span[text()='Next']/.."))).click()

        time.sleep(2)

        wait.until(EC.presence_of_element_located((By.XPATH, f"//span[text()='Not now']/.."))).click()

        time.sleep(2)
    except:
        try:
            wait.until(EC.presence_of_element_located((By.XPATH, f"//span[text()='Not now']/.."))).click()
        except:pass
        
    #Getting the gmail of Facebook                          xpath              "/.." ---> is kae uper wala parent element mil jae
    wait.until(EC.presence_of_element_located((By.XPATH,"(//*[text()='Facebook']/..)[2]/../../.."))).click()
    time.sleep(5)
    # getting the code
    code = driver.find_element(By.XPATH,"//td[@style='font-size:20px;font-family:LucidaGrande,tahoma,verdana,arial,sans-serif;padding:10px;background-color:#f2f2f2;border-left:1px solid #ccc;border-right:1px solid #ccc;border-top:1px solid #ccc;border-bottom:1px solid #ccc']").text
    print('[+] Code is ', code)
    # switching to the previous tab
    driver.switch_to.window(driver.window_handles[0])# 0 means first tab remember python syntax

    # replacing FB- from the code 
    code = code.replace('FB-','')
    
    time.sleep(3)
    #input the code 
    code_holder = driver.find_element(By.XPATH,"//input[@name='code']")
    code_holder.send_keys(code)
    
    driver.find_element(By.XPATH,"//button[text()='Continue']").click()
    
    time.sleep(10)
    
    try:
        driver.find_element(By.XPATH,"//a[@class='_42ft _42fu layerCancel uiOverlayButton selected _42g- _42gy']").click()
        time.sleep(1)
    except:pass
    
    time.sleep(10)
    n += 1
    
    driver.quit()
# Out:
# Email :  chistinanadia458@gmail.com Password :  uk789112cxh
# [+] Code is  FB-52785
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14028\796362213.py in <module>
#       7     passw = df["Password"][n]
#       8
# ----> 9     get_chrome()
#      10     wait = WebDriverWait(driver, 15)
#      11     time.sleep(10)
#
# ~\AppData\Local\Temp\ipykernel_14028\975153828.py in get_chrome()
#       8     chrome_options.add_argument('--disable-popup-blocking')
#       9
# ---> 10     driver = uc.Chrome(options=chrome_options)
# ...
